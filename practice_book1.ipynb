-- %%
%sql
create table test_table (id int, first_name string, last_name string, middle_name string, age int) partitioned by (age)

-- %%
%sql
insert into test_table values (1, 'Someshwar', 'Giddigam', 'R', 48), (2, 'Karunasri', 'Komuravelli', '', 48), (3, 'Chinmai', 'Giddigam', '', 20), (4, 'Purvaja', 'Giddigam', 'B', 14);

-- %%
%sql
describe extended test_table

-- %%
select * from test_table

-- %%
create table test_table_2 partitioned by (middle_name) as select id, first_name, last_name, middle_name from test_table

-- %%
insert into test_table_2 values(5, 'Somanarasaiah', 'Giddigam', 'R')

-- %%
describe history test_table_2

-- %%
create view test_view as select * from test_table where age = 48

-- %%
create temporary view test_view_2 as select * from test_table where last_name = 'Giddigam'

-- %%
show views

-- %%
select * from test_view_2

-- %%
create global temporary view test_view_3 as select * from test_table where last_name != 'Giddigam'
